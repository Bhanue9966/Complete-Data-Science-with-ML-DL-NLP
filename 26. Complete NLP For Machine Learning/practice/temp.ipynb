# %%
# !pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.6 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
# ...
